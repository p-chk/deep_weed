# %%
# !pip3 install keras
# !pip3 install tensorflow
# !pip3 install pydot
# !pip3 install graphviz
# Import
import keras,os
from keras.models import Sequential, Model
from keras.callbacks import CSVLogger
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Input, concatenate, AveragePooling2D,Dropout
from keras.utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
# from google.colab import drive
import pandas as pd
import shutil
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# Requirement already satisfied: keras in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: tensorflow in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: tensorflow-macos==2.14.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.25.0)
# Requirement already satisfied: setuptools in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.2.2)
# Requirement already satisfied: pydot in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (from pydot) (3.0.9)
# Requirement already satisfied: graphviz in /Users/chayakornk/anaconda3/lib/python3.11/site-packages (0.20.1)

# %%
data = pd.read_csv("archive/labels/labels.csv")
data
# Out:
#                     Filename  Label       Species
# 0      20160928-140314-0.jpg      0  Chinee apple
# 1      20160928-140337-0.jpg      0  Chinee apple
# 2      20160928-140731-0.jpg      0  Chinee apple
# 3      20160928-140747-0.jpg      0  Chinee apple
# 4      20160928-141107-0.jpg      0  Chinee apple
# ...                      ...    ...           ...
# 17504  20180322-133822-1.jpg      8      Negative
# 17505  20180322-133832-1.jpg      8      Negative
# 17506  20180322-133840-1.jpg      8      Negative
# 17507  20180322-133850-1.jpg      8      Negative
# 17508  20180322-133901-1.jpg      8      Negative
#
# [17509 rows x 3 columns]

# %%
data.drop(columns='Species')
print(data['Label'].value_counts())
# Out:
# Label
# 8    9106
# 0    1125
# 6    1074
# 1    1064
# 4    1062
# 2    1031
# 3    1022
# 7    1016
# 5    1009
# Name: count, dtype: int64

# %%
#Split data 80 / 20, due to performance utilizng only 70%
sliced_data = data.groupby('Label').sample(frac=0.7, random_state=2)
sliced_data = sliced_data.drop(sliced_data[sliced_data.Label==8].groupby('Label').sample(frac=0.9, random_state=2).index)
train = sliced_data.groupby('Label').sample(frac=0.8, random_state=2)
test = sliced_data.drop(train.index)

# %%
print(train['Label'].value_counts())
print(test['Label'].value_counts())
# Out:
# Label
# 0    90
# 6    86
# 1    85
# 4    85
# 2    82
# 3    82
# 7    82
# 5    81
# 8    73
# Name: count, dtype: int64
# Label
# 0    22
# 1    21
# 2    21
# 4    21
# 6    21
# 3    20
# 5    20
# 7    20
# 8    18
# Name: count, dtype: int64

# %%
! mkdir archive/train
! mkdir archive/train/0 archive/train/1 archive/train/2 archive/train/3 archive/train/4 archive/train/5 archive/train/6 archive/train/7 archive/train/8

! mkdir archive/test
! mkdir archive/test/0 archive/test/1 archive/test/2 archive/test/3 archive/test/4 archive/test/5 archive/test/6 archive/test/7 archive/test/8

# %%
for index, row in train.iterrows():
  shutil.copyfile("archive/images/" + row["Filename"], "archive/train/" + str(row["Label"]) + "/" + row["Filename"])

# %%
for index, row in test.iterrows():
  shutil.copyfile("archive/images/" + row["Filename"], "archive/test/" + str(row["Label"]) + "/" + row["Filename"])

# %%
train_data_gr = ImageDataGenerator(
    horizontal_flip=True,
    zoom_range=0.5,
    rotation_range=30
    )
train_data = train_data_gr.flow_from_directory(directory="archive/train", target_size=(224, 224))
train_data_ge = ImageDataGenerator()
test_data = train_data_gr.flow_from_directory(directory="archive/test", target_size=(224, 224))
# Out:
# Found 746 images belonging to 9 classes.
# Found 184 images belonging to 9 classes.

# %%
#VGG16
vgg16model = Sequential()
vgg16model.add(Conv2D(input_shape=(224, 224, 3), filters=64, kernel_size=(3, 3),padding="same", activation="relu"))
vgg16model.add(Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"))
vgg16model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
vgg16model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
vgg16model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
vgg16model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
vgg16model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
vgg16model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
vgg16model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
vgg16model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
# vgg16model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
# vgg16model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
# vgg16model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
# vgg16model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
# vgg16model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
# vgg16model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
# vgg16model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
# vgg16model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
vgg16model.add(Flatten())
vgg16model.add(Dense(units=4096,activation="relu"))
vgg16model.add(Dense(units=4096,activation="relu"))
vgg16model.add(Dense(units=9, activation="softmax"))

# %%
vgg16model.compile(optimizer="sgd", loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
vgg16model.summary()
plot_model(vgg16model, show_shapes=True, to_file='archive/vgg16_module.png')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 200704)            0
#
#  dense (Dense)               (None, 4096)              822087680
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 9)                 36873
#
# =================================================================
# Total params: 840641353 (3.13 GB)
# Trainable params: 840641353 (3.13 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
csv_logger = CSVLogger( 'archive/vgg16-training.log', separator=',', append=False)
vgg16model_fitted = vgg16model.fit(x=train_data, validation_data=test_data, callbacks=[csv_logger], epochs=5, shuffle=True, batch_size=32)
# Out:
# Epoch 1/5
# 24/24 [==============================] - 320s 13s/step - loss: 2.1961 - accuracy: 0.1206 - val_loss: 2.1960 - val_accuracy: 0.1196
# Epoch 2/5
# 24/24 [==============================] - 202s 9s/step - loss: 2.1961 - accuracy: 0.1206 - val_loss: 2.1960 - val_accuracy: 0.1196
# Epoch 3/5
# 24/24 [==============================] - 213s 9s/step - loss: 2.1961 - accuracy: 0.1206 - val_loss: 2.1960 - val_accuracy: 0.1196
# Epoch 4/5
# 24/24 [==============================] - 200s 8s/step - loss: 2.1961 - accuracy: 0.1206 - val_loss: 2.1960 - val_accuracy: 0.1196
# Epoch 5/5
# 24/24 [==============================] - 199s 8s/step - loss: 2.1961 - accuracy: 0.1206 - val_loss: 2.1960 - val_accuracy: 0.1196

# %%
vgg16model.save('archive/vgg16.keras')

# %%
vgg16model = tf.keras.models.load_model('archive/vgg16.keras')

# %%
vgg_16model_history = pd.read_csv('archive/vgg16-training.log', sep=',', engine='python')

# %%
plt.plot(vgg_16model_history['accuracy'])
plt.title('trainning accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(vgg_16model_history['val_accuracy'])
plt.title('test accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['test'], loc='upper left')
plt.show()

# %%
plt.plot(vgg_16model_history['loss'])
plt.title('trainning loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(vgg_16model_history['val_loss'])
plt.title('testing loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['test'], loc='upper left')
plt.show()

# %%
# Inception
def inception_block(input, f1, f2_in, f2_out, f3_in, f3_out, f4_out):
 conv1 = Conv2D(f1, (1,1), activation='relu', padding='same')(input)
 max_pool = MaxPool2D((3,3), strides=(1,1), padding='same')(input)

 conv3 = Conv2D(f2_in, (1,1), activation='relu', padding='same')(input)
 conv3 = Conv2D(f2_out, (3,3), activation='relu', padding='same')(conv3)

 conv5 = Conv2D(f3_in, (1,1), activation='relu', padding='same')(input)
 conv5 = Conv2D(f3_out, (5,5), activation='relu', padding='same')(conv5)

 max_pool = Conv2D(f4_out, (1,1), activation='relu', padding='same')(max_pool)

 return concatenate([conv1, conv3, conv5, max_pool], axis=-1)

# %%
# Inception
# model input
input = Input(shape=(224, 224, 3))
layer = Conv2D(64, (7,7), activation='relu')(input)
layer = MaxPool2D((3,3), strides=(2,2))(layer)
layer = Conv2D(192, (3,3), activation='relu')(layer)
layer = MaxPool2D((3,3), strides=(2,2))(layer)
layer = inception_block(layer, 64, 96, 128, 16, 32, 32)
layer = inception_block(layer, 128, 128, 192, 32, 96, 64)
layer = MaxPool2D((3,3), strides=(2,2))(layer)

layer = inception_block(layer, 192, 96, 208, 16, 48, 64)
layer = inception_block(layer, 160, 112, 224, 24, 64, 64)
layer = inception_block(layer, 128, 128, 256, 24, 64, 64)
layer = inception_block(layer, 112, 144, 288, 32, 64, 64)
layer = inception_block(layer, 256, 160, 320, 32, 128, 128)

layer = MaxPool2D((3,3), strides=(2,2))(layer)
layer = inception_block(layer, 256, 160, 320, 32, 128, 128)
layer = inception_block(layer, 384, 192, 384, 48, 128, 128)
layer = AveragePooling2D((7, 7), strides=(1, 1))(layer)
layer = Dropout(0.4)(layer)
layer = Flatten()(layer)
layer = Dense(9, activation="softmax")(layer)

inception = Model(inputs=input, outputs=layer)
# summarize model
inception.summary()
# plot model architecture
plot_model(inception, show_shapes=True, to_file='archive/inception_module.png')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_7 (Conv2D)           (None, 218, 218, 64)         9472      ['input_1[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 108, 108, 64)         0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 106, 106, 192)        110784    ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 52, 52, 192)          0         ['conv2d_8[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 96)           18528     ['max_pooling2d_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 52, 52, 16)           3088      ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 52, 52, 192)          0         ['max_pooling2d_4[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 52, 52, 64)           12352     ['max_pooling2d_4[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 52, 52, 128)          110720    ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 52, 52, 32)           12832     ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 52, 52, 32)           6176      ['max_pooling2d_5[0][0]']
#
#  concatenate (Concatenate)   (None, 52, 52, 256)          0         ['conv2d_9[0][0]',
#                                                                      'conv2d_11[0][0]',
#                                                                      'conv2d_13[0][0]',
#                                                                      'conv2d_14[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 52, 52, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 52, 52, 32)           8224      ['concatenate[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 52, 52, 256)          0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 52, 52, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 52, 52, 192)          221376    ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 52, 52, 96)           76896     ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 52, 52, 64)           16448     ['max_pooling2d_6[0][0]']
#
#  concatenate_1 (Concatenate  (None, 52, 52, 480)          0         ['conv2d_15[0][0]',
#  )                                                                   'conv2d_17[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 25, 25, 480)          0         ['concatenate_1[0][0]']
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 25, 25, 96)           46176     ['max_pooling2d_7[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 25, 25, 16)           7696      ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 25, 25, 480)          0         ['max_pooling2d_7[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 25, 25, 192)          92352     ['max_pooling2d_7[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 25, 25, 208)          179920    ['conv2d_22[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 25, 25, 48)           19248     ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 25, 25, 64)           30784     ['max_pooling2d_8[0][0]']
#
#  concatenate_2 (Concatenate  (None, 25, 25, 512)          0         ['conv2d_21[0][0]',
#  )                                                                   'conv2d_23[0][0]',
#                                                                      'conv2d_25[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 25, 25, 112)          57456     ['concatenate_2[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 25, 25, 24)           12312     ['concatenate_2[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 25, 25, 512)          0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 25, 25, 160)          82080     ['concatenate_2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 25, 25, 224)          226016    ['conv2d_28[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 25, 25, 64)           38464     ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 64)           32832     ['max_pooling2d_9[0][0]']
#
#  concatenate_3 (Concatenate  (None, 25, 25, 512)          0         ['conv2d_27[0][0]',
#  )                                                                   'conv2d_29[0][0]',
#                                                                      'conv2d_31[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 25, 25, 24)           12312     ['concatenate_3[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 25, 25, 512)          0         ['concatenate_3[0][0]']
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 256)          295168    ['conv2d_34[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 25, 25, 64)           38464     ['conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 25, 25, 64)           32832     ['max_pooling2d_10[0][0]']
#
#  concatenate_4 (Concatenate  (None, 25, 25, 512)          0         ['conv2d_33[0][0]',
#  )                                                                   'conv2d_35[0][0]',
#                                                                      'conv2d_37[0][0]',
#                                                                      'conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 25, 25, 144)          73872     ['concatenate_4[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 25, 25, 32)           16416     ['concatenate_4[0][0]']
#
#  max_pooling2d_11 (MaxPooli  (None, 25, 25, 512)          0         ['concatenate_4[0][0]']
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 25, 25, 112)          57456     ['concatenate_4[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 25, 25, 288)          373536    ['conv2d_40[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 25, 25, 64)           51264     ['conv2d_42[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 25, 25, 64)           32832     ['max_pooling2d_11[0][0]']
#
#  concatenate_5 (Concatenate  (None, 25, 25, 528)          0         ['conv2d_39[0][0]',
#  )                                                                   'conv2d_41[0][0]',
#                                                                      'conv2d_43[0][0]',
#                                                                      'conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 25, 25, 160)          84640     ['concatenate_5[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 25, 25, 32)           16928     ['concatenate_5[0][0]']
#
#  max_pooling2d_12 (MaxPooli  (None, 25, 25, 528)          0         ['concatenate_5[0][0]']
#  ng2D)
#
#  conv2d_45 (Conv2D)          (None, 25, 25, 256)          135424    ['concatenate_5[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 25, 25, 320)          461120    ['conv2d_46[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 25, 25, 128)          102528    ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 25, 25, 128)          67712     ['max_pooling2d_12[0][0]']
#
#  concatenate_6 (Concatenate  (None, 25, 25, 832)          0         ['conv2d_45[0][0]',
#  )                                                                   'conv2d_47[0][0]',
#                                                                      'conv2d_49[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  max_pooling2d_13 (MaxPooli  (None, 12, 12, 832)          0         ['concatenate_6[0][0]']
#  ng2D)
#
#  conv2d_52 (Conv2D)          (None, 12, 12, 160)          133280    ['max_pooling2d_13[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 12, 12, 32)           26656     ['max_pooling2d_13[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 12, 12, 832)          0         ['max_pooling2d_13[0][0]']
#  ng2D)
#
#  conv2d_51 (Conv2D)          (None, 12, 12, 256)          213248    ['max_pooling2d_13[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 12, 12, 320)          461120    ['conv2d_52[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 12, 12, 128)          102528    ['conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 12, 12, 128)          106624    ['max_pooling2d_14[0][0]']
#
#  concatenate_7 (Concatenate  (None, 12, 12, 832)          0         ['conv2d_51[0][0]',
#  )                                                                   'conv2d_53[0][0]',
#                                                                      'conv2d_55[0][0]',
#                                                                      'conv2d_56[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 12, 12, 192)          159936    ['concatenate_7[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 12, 12, 48)           39984     ['concatenate_7[0][0]']
#
#  max_pooling2d_15 (MaxPooli  (None, 12, 12, 832)          0         ['concatenate_7[0][0]']
#  ng2D)
#
#  conv2d_57 (Conv2D)          (None, 12, 12, 384)          319872    ['concatenate_7[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 12, 12, 384)          663936    ['conv2d_58[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 12, 12, 128)          153728    ['conv2d_60[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 12, 12, 128)          106624    ['max_pooling2d_15[0][0]']
#
#  concatenate_8 (Concatenate  (None, 12, 12, 1024)         0         ['conv2d_57[0][0]',
#  )                                                                   'conv2d_59[0][0]',
#                                                                      'conv2d_61[0][0]',
#                                                                      'conv2d_62[0][0]']
#
#  average_pooling2d (Average  (None, 6, 6, 1024)           0         ['concatenate_8[0][0]']
#  Pooling2D)
#
#  dropout (Dropout)           (None, 6, 6, 1024)           0         ['average_pooling2d[0][0]']
#
#  flatten_1 (Flatten)         (None, 36864)                0         ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 9)                    331785    ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 6301177 (24.04 MB)
# Trainable params: 6301177 (24.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
inception.compile(optimizer='adam', loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
csv_logger = CSVLogger( 'archive/inception-training.log', separator=',', append=False)
inceptionmodel_fitted = inception.fit(x=train_data, validation_data=test_data, callbacks=[csv_logger], epochs=5, shuffle=True, batch_size=32)
# Out:
# Epoch 1/5
# 24/24 [==============================] - 94s 4s/step - loss: 3.1302 - accuracy: 0.1220 - val_loss: 2.2008 - val_accuracy: 0.1196
# Epoch 2/5
# 24/24 [==============================] - 91s 4s/step - loss: 2.2011 - accuracy: 0.1206 - val_loss: 2.1941 - val_accuracy: 0.1196
# Epoch 3/5
# 24/24 [==============================] - 91s 4s/step - loss: 2.1962 - accuracy: 0.1220 - val_loss: 2.1965 - val_accuracy: 0.2011
# Epoch 4/5
# 24/24 [==============================] - 91s 4s/step - loss: 2.1984 - accuracy: 0.1046 - val_loss: 2.1967 - val_accuracy: 0.1141
# Epoch 5/5
# 24/24 [==============================] - 90s 4s/step - loss: 2.1973 - accuracy: 0.1247 - val_loss: 2.1933 - val_accuracy: 0.1141

# %%
inception.save('archive/inception.keras')

# %%
inception = tf.keras.models.load_model('archive/inception.keras')

# %%
inceptionmodel_history = pd.read_csv('archive/inception-training.log', sep=',', engine='python')

# %%
plt.plot(inceptionmodel_history['accuracy'])
plt.title('trainning accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(inceptionmodel_history['val_accuracy'])
plt.title('test accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['test'], loc='upper left')
plt.show()

# %%
plt.plot(inceptionmodel_history['loss'])
plt.title('trainning loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(inceptionmodel_history['val_loss'])
plt.title('testing accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['test'], loc='upper left')
plt.show()
